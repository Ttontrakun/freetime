# %%
import random

def future_prediction():
    predictions = [
        "คุณจะได้รับโชคดีในเร็วๆ นี้",
        "มีโอกาสดีรอคุณอยู่ข้างหน้า",
        "อย่าลืมให้ความสำคัญกับคนรอบข้าง",
        "วันนี้จะเป็นวันที่ดีสำหรับคุณ",
        "ระวังอุบัติเหตุเล็กน้อย",
        "มีโอกาสใหม่ๆ ที่คุณจะต้องตัดสินใจ",
        "จงเชื่อมั่นในตัวเองและสิ่งที่คุณทำ",
        "ความสำเร็จใกล้แค่เอื้อม",
        "คำแนะนำจากคนใกล้ตัวจะช่วยให้คุณก้าวหน้ามากขึ้น",
        "คุณจะพบกับการเปลี่ยนแปลงที่ดีในอนาคต",
        "ความรักกำลังจะมาถึงคุณ",
        "มีโอกาสเดินทางไกลในอนาคตอันใกล้",
        "การตัดสินใจในวันนี้จะส่งผลดีในอนาคต",
        "คุณจะได้พบกับคนที่มีความคิดเหมือนคุณ",
        "เวลาที่ผ่านมาจะช่วยเสริมสร้างคุณให้แข็งแกร่งขึ้น",
        "การทำงานหนักของคุณจะได้รับผลตอบแทนที่คุ้มค่า",
        "อย่ากลัวที่จะลองสิ่งใหม่ๆ",
        "คุณจะได้รับคำชมจากผลงานของคุณในเร็วๆ นี้",
        "มีข่าวดีรอคุณอยู่ในอนาคต",
        "ความฝันของคุณจะกลายเป็นจริง",
        "ระวังการตัดสินใจผิดพลาดในช่วงนี้",
        "สิ่งที่คุณหวังอาจจะไม่เป็นไปตามที่คิด",
        "อย่าลืมพักผ่อนให้เพียงพอในช่วงนี้",
        "อาจมีความขัดแย้งเกิดขึ้นในช่วงนี้",
        "ระวังการถูกหลอกลวงหรือเสียเงินในช่วงนี้",
        "คุณอาจเจออุปสรรคที่ทำให้คุณท้อใจ",
        "ช่วงนี้คุณอาจจะรู้สึกเหนื่อยกับการทำงาน",
        "ความสัมพันธ์บางอย่างอาจจะมีปัญหาในเร็วๆ นี้",
        "ระวังการทำสิ่งที่อาจทำให้คุณเสียใจในภายหลัง",
        "คุณอาจจะต้องเผชิญกับการสูญเสียบางอย่าง",
        "อย่าละเลยสุขภาพของตัวเองในช่วงนี้",
        "มีความท้าทายที่คุณต้องเตรียมตัวให้พร้อม"
    ]
    
    print("โปรแกรมทำนายอนาคต!")
    input("กด Enter เพื่อทำนายอนาคตของคุณ...")
    
    prediction = random.choice(predictions)
    print(f"คำทำนาย: {prediction}")

future_prediction()
# Out:
# โปรแกรมทำนายอนาคต!
# คำทำนาย: ช่วงนี้คุณอาจจะรู้สึกเหนื่อยกับการทำงาน

# %%
import random

def predict_life():
    good_predictions = [
        "วันนี้คุณจะพบกับความสำเร็จ",
        "วันนี้คุณจะได้รับข่าวดี",
        "วันนี้คุณจะมีความสุขมาก",
        "วันนี้คุณจะได้พบกับเพื่อนใหม่",
        "วันนี้คุณจะได้รับคำชมจากคนรอบข้าง",
        "วันนี้คุณจะมีโอกาสใหม่ๆ",
        "วันนี้คุณจะได้เรียนรู้สิ่งใหม่ๆ",
        "วันนี้คุณจะมีความก้าวหน้าในงาน",
        "วันนี้คุณจะได้รับความช่วยเหลือจากคนใกล้ตัว",
        "วันนี้คุณจะมีโชคดีในเรื่องการเงิน"
    ]
    
    bad_predictions = [
        "วันนี้คุณอาจจะพบกับความล้มเหลว",
        "วันนี้คุณอาจจะได้รับข่าวร้าย",
        "วันนี้คุณอาจจะมีความทุกข์",
        "วันนี้คุณอาจจะมีปัญหากับเพื่อน",
        "วันนี้คุณอาจจะถูกวิจารณ์จากคนรอบข้าง",
        "วันนี้คุณอาจจะพลาดโอกาสดีๆ",
        "วันนี้คุณอาจจะเจอเรื่องที่ไม่คาดคิด",
        "วันนี้คุณอาจจะมีปัญหาในงาน",
        "วันนี้คุณอาจจะไม่ได้รับความช่วยเหลือจากคนใกล้ตัว",
        "วันนี้คุณอาจจะมีปัญหาเรื่องการเงิน"
    ]
    
    print("โปรแกรมทำนายชีวิตในวันนี้!")
    input("กด Enter เพื่อทำนายชีวิตของคุณวันนี้...")
    
    prediction_type = random.choice(['good', 'bad'])
    if prediction_type == 'good':
        prediction = random.choice(good_predictions)
    else:
        prediction = random.choice(bad_predictions)
    
    print(f"คำทำนาย: {prediction}")


predict_life()
# Out:
# โปรแกรมทำนายชีวิตในวันนี้!
# คำทำนาย: วันนี้คุณจะมีความก้าวหน้าในงาน
